# %%
from wordcloud import WordCloud, STOPWORDS
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("./spam_data/Youtube04-Eminem.csv", encoding = "latin-1")

# %%
df
# Out:
#                                       COMMENT_ID  \
# 0              z12rwfnyyrbsefonb232i5ehdxzkjzjs2
# 1            z130wpnwwnyuetxcn23xf5k5ynmkdpjrj04
# 2              z13vsfqirtavjvu0t22ezrgzyorwxhpf3
# 3            z12wjzc4eprnvja4304cgbbizuved35wxcs
# 4              z13xjfr42z3uxdz2223gx5rrzs3dt5hna
# ..                                           ...
# 443  LneaDw26bFu3RCmyrWyP9S6wh1h9dBv3X95g1HzKAb4
# 444  LneaDw26bFsD65dtIvAEObWYIYnFTqQDKBek_Ypz3J8
# 445  LneaDw26bFuvs-8oWkLpAFa6g3QHpWD8k7sbbMP3Bg8
# 446        z12hfp2wmyuqztkw504cgblyxtbsxjuzeow0k
# 447          z13tsbc5vvn0hdozz04chjt51lq1cvris0k
#
#                              AUTHOR                        DATE  \
# 0                       Lisa Wellas                         NaN
# 1                      jason graham  2015-05-29T02:26:10.652000
# 2                        Ajkal Khan                         NaN
# 3                     Dakota Taylor  2015-05-29T02:13:07.810000
# ...

# %%
comment_words = ''
stopwords = set(STOPWORDS)

# %%
for val in df.CONTENT:
    val = str(val)
    tokens = val.split()
    
    for i in range(len(tokens)):
        tokens[i] = tokens[i].lower()
    
    comment_words += " ".join(tokens) + " "

# %%
wordcloud = WordCloud(width = 800, height = 800,
                     background_color = "white",
                     stopwords = stopwords,
                     min_font_size = 10).generate(comment_words)

# %%
plt.figure(figsize=(8,8), facecolor= None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)

plt.show()

# %% [markdown]
# # Opening CSV file

# %%
import csv
import re

# %%
file = open("E:\\programming\\Project\\NLP\\spam_data\\WhatsApp Chat with vit_Mrunal.txt", 'r', encoding = ('utf-8'))

# %%
file
# Out:
# <_io.TextIOWrapper name='E:\\programming\\Project\\NLP\\spam_data\\WhatsApp Chat with vit_Mrunal.txt' mode='r' encoding='utf-8'>

# %%
chat = file.readlines()

# %%
chat
# Out:
# ['04/11/2021, 12:30 - Messages and calls are end-to-end encrypted. No one outside of this chat, not even WhatsApp, can read or listen to them. Tap to learn more.\n',
#  '04/11/2021, 12:29 - vit_Mrunal: Happy Diwali 🪔\n',
#  '04/11/2021, 13:03 - Anubhav: Hey, happy diwali man 😊\n',
#  '04/11/2021, 13:12 - vit_Mrunal: 😁\n',
#  '10/11/2021, 19:56 - vit_Mrunal: come for dinner\n',
#  '10/11/2021, 19:56 - vit_Mrunal: j block\n',
#  '10/11/2021, 19:57 - Anubhav: Ogay\n',
#  '10/11/2021, 20:02 - Anubhav: I am here\n',
#  '12/11/2021, 19:16 - Anubhav: When will you go for dinner?\n',
#  '12/11/2021, 19:18 - vit_Mrunal: abhi chale?\n',
#  '12/11/2021, 19:21 - Anubhav: Tere ko bhookh hai?\n',
#  '12/11/2021, 19:21 - Anubhav: 7:45 soch rha tha mai\n',
#  '12/11/2021, 19:21 - Anubhav: I got little shoulder problem to vo dekh rha hoon\n',
#  '12/11/2021, 19:28 - vit_Mrunal: haan i reached actually\n',
#  '12/11/2021, 19:28 - vit_Mrunal: kya hua?\n',
# ...

# %%
finalList = list()

for i in range(len(chat)):
    s = chat[i]
    if re.search(r"^[0-9][0-9]/[0-9][0-9]/[0-9][0-9]", s):
        time = s[s.find(','):s.find('-', s.find(','))]
        date = s[0:s.find(',')]
        Sender = s[s.find('-'):s.find(':',s.find('-'))]
        Message = s[s.find(':',s.find('-')):]

        temp_list = list()
        temp_list.append(date)
        temp_list.append(time)
        temp_list.append(Sender)
        temp_list.append(Message)

        finalList.append(temp_list)

    else:
        Msg = finalList[-1][3]
        Cht = Msg.join([" ", s])
        finalList[-1][3] = Cht

# %%
finalList
# Out:
# [['11/06/2021', ', 00:21 ', '- Anubhav', ': oh bad\n'],
#  ['11/06/2021', ', 00:21 ', '- Anubhav', ': yahan aaye hue 20 mins ho gye\n'],
#  ['11/06/2021',
#   ', 08:54 ',
#   '- Bublasaur',
#   ': aa gyi thi humare yaha bhi around 12.30-1\n'],
#  ['11/06/2021', ', 11:15 ', '- Bublasaur', ': hello??\n'],
#  ['11/06/2021', ', 11:35 ', '- Anubhav', ': hello\n'],
#  ['11/06/2021', ', 11:35 ', '- Bublasaur', ': hi\n'],
#  ['11/06/2021', ', 11:36 ', '- Bublasaur', ': i took first half off\n'],
#  ['11/06/2021',
#   ', 11:36 ',
#   '- Bublasaur',
#   ': because ac repair jo rha hai mere room mei\n'],
#  ['11/06/2021', ', 11:36 ', '- Bublasaur', ": and I can't work there\n"],
#  ['11/06/2021', ', 11:36 ', '- Anubhav', ': kewl\n'],
#  ['11/06/2021', ', 11:36 ', '- Anubhav', ': gg\n'],
#  ['11/06/2021', ', 11:46 ', '- Bublasaur', ': wachu doing\n'],
#  ['11/06/2021', ', 11:58 ', '- Anubhav', ': abhi utha hoo\n'],
#  ['11/06/2021', ', 11:58 ', '- Anubhav', ': 5 baje soya\n'],
# ...

# %%
with open('Chat.csv','w', encoding=('utf-16')) as f:
            writer = csv.writer(f)
            writer.writerow(['Date','Time', 'Sender', 'Message'])
            writer.writerows(finalList)
print("'Chat.csv' successfully created.")
# Out:
# 'Chat.csv' successfully created.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('Chat.csv', encoding=('utf-16'))
data.drop('Time', axis = 1, inplace = True)
data['Sender'] = data['Sender'].str.lstrip('- ')
data['Message'] = data['Message'].str.lstrip(': ')

# %%
data[10:40]
#<Media omitted>\r\n
# Out:
#           Date     Sender                         Message
# 10  11/06/2021    Anubhav                              gg
# 11  11/06/2021  Bublasaur                     wachu doing
# 12  11/06/2021    Anubhav                   abhi utha hoo
# 13  11/06/2021    Anubhav                     5 baje soya
# 14  11/06/2021    Anubhav  pidhai kari thodi aur raat mei
# 15  11/06/2021  Bublasaur                        oh wowow
# 16  11/06/2021  Bublasaur              chalo that is good
# 17  11/06/2021  Bublasaur         humara ac bann gya 🫂🥳🥳🥳
# 18  11/06/2021    Anubhav                   yaaaayyayayay
# 19  11/06/2021    Anubhav                            ggwp
# 20  11/06/2021    Anubhav                              🥳🤩
# 21  11/06/2021  Bublasaur                               🫂
# 22  11/06/2021  Bublasaur               ab jhadu lagaungi
# 23  11/06/2021  Bublasaur                    And nahaungi
# 24  11/06/2021  Bublasaur                 and fresh fresh
# ...

# %%
Messengers = data['Sender'].unique()
#Messengers = np.delete(Messengers, [0,1,6,7])
Messengers
# Out:
# array(['Messages and calls are end-to-end encrypted. No one outside of this chat, not even WhatsApp, can read or listen to them. Tap to learn more.',
#        'vit_Mrunal', 'Anubhav'], dtype=object)

# %%
Messengers = np.delete(Messengers, [0])
Messengers
# Out:
# array(['vit_Mrunal', 'Anubhav'], dtype=object)

# %%
for i in range(len(data.Message)):
    if data.Message[i] == '<Media omitted>\r\n':
        data.Message[i] = 'Meme'

# %%
data.Message = data.Message.str.rstrip('\r\n')

# %%
comment_words = ''
stopwords = set(STOPWORDS)

# %%
for val in data.Message:
    val = str(val)
    tokens = val.split()
    
    for i in range(len(tokens)):
        tokens[i] = tokens[i].lower()
    
    comment_words += " ".join(tokens) + " "

# %%
wordcloud = WordCloud(width = 800, height = 800,
                     background_color = "white",
                     stopwords = stopwords,
                     min_font_size = 10).generate(comment_words)

# %%
plt.figure(figsize=(8,8), facecolor= None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)

plt.show()
